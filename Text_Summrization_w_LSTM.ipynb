# %% [markdown]
# # FUNCTIONS AND GLOBAL VARIABLES

# %% [markdown]
# ## Install & Import Libraries

# %%
#Python >=3.9, only run for the first time
#%pip install -r requirements.txt

# %%
from tensorflow.keras.layers import Attention as AttentionLayer
import numpy as np
import pandas as pd
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
import nltk
import os
import tensorflow as tf
from keras import backend as K
from sklearn.model_selection import train_test_split
from rouge_score import rouge_scorer
import re
from bs4 import BeautifulSoup as BS
import gdown
import os

# %% [markdown]
# ## Global Variables

# %%
MAX_LEN_TXT = 100
MAX_LEN_SUM = 20
PATH_TO_DATA = './data/'
PATH_TO_MODELS = './model/'
PATH_TO_CHECKPOINT = './ckpt/'
SAMPLES = 400000
STOPWORDS_REMOVAL = True
EMBED_DIM = 300

# %% [markdown]
# ## Download Models

# %%
if os.path.isfile("".join([PATH_TO_MODELS,'200000_100d_nostop_80_10.h5']))==False:
    output = "".join([PATH_TO_MODELS,'200000_100d_nostop_80_10.h5'])
    url = "https://drive.google.com/file/d/1V0cjoCCDB7JWwta8bnWTAlNSNNtyXy6Q/view?usp=drive_link"
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)

if os.path.isfile("".join([PATH_TO_MODELS,'200000_100d_nostop_100_20.h5']))==False:
    output = "".join([PATH_TO_MODELS,'200000_100d_nostop_100_20.h5'])
    url = "https://drive.google.com/file/d/1cNhTrgYjbKa1J6UBn9tN0U8LRnpIxq0-/view?usp=drive_link"
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)

if os.path.isfile("".join([PATH_TO_MODELS,'400000_300d_fullstop_100_20.h5']))==False:
    output = "".join([PATH_TO_MODELS,'400000_300d_fullstop_100_20.h5'])
    url = "https://drive.google.com/file/d/1M4fxm7isYtxcrflOsa_lIQDcs_k8JWvH/view?usp=drive_link"
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)

if os.path.isfile("".join([PATH_TO_MODELS,'400000_300d_nostop_100_20.h5']))==False:
    output = "".join([PATH_TO_MODELS,'400000_300d_nostop_100_20.h5'])
    url = "https://drive.google.com/file/d/1U0vWsb1xuduEIOO6-cALJEfwby9vD3hR/view?usp=drive_link"
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)
    
if os.path.isfile("".join([PATH_TO_MODELS,'glove.6B.100d.txt']))==False:
    output = "".join([PATH_TO_MODELS,'glove.6B.100d.txt'])
    url = "https://drive.google.com/file/d/1hxQIMX-TjR8eXbjmUEDanPzLkKH2a9ac/view?usp=drive_link"
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)

if os.path.isfile("".join([PATH_TO_MODELS,'glove.6B.300d.txt']))==False:
    output = "".join([PATH_TO_MODELS,'glove.6B.300d.txt'])
    url = "https://drive.google.com/file/d/1Jc7BBiC18uSC7tZxNRn7FLijpBzLL4U9/view?usp=drive_link"
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)

if os.path.isfile("".join([PATH_TO_DATA,'Reviews.csv']))==False:
    output = "".join([PATH_TO_DATA,'Reviews.csv'])
    url = "https://drive.google.com/file/d/1Mg6iyiwvrC4YzejDmmSDt4ajv3cLoVLT/view?usp=drive_link"
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)

# %% [markdown]
# ## Data Preprocessing Functions

# %% [markdown]
# ### Data Cleaning

# %%
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

nltk.download('stopwords')
# Remove stopwords
stop_words = set(stopwords.words('english'))


contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}



def clean_line(text,num):
    '''Use to clean up lines per rows in the dataset'''
    line = text.lower()
    line = BS(line, "lxml").text
    line = re.sub(r'\([^)]*\)', '', line)
    line = re.sub('"','', line)
    line = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in line.split(" ")])
    line = re.sub(r"'s\b","",line)
    line = re.sub("[^a-zA-Z]", " ", line)
    line = re.sub('[m]{2,}', 'mm', line)
    if(num==0):
        tokens = [w for w in line.split() if not w in stop_words]
    else:
        tokens=line.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:
            long_words.append(i)
    return (" ".join(long_words)).strip()

def cleaner(option):
    '''Cleaner main functions'''
    data=pd.read_csv("".join([PATH_TO_DATA,"Reviews.csv"]),nrows=SAMPLES,usecols=[8,9])
    data.drop_duplicates(subset=['Text'],inplace=True)
    data.dropna(axis=0,inplace=True)
    data = data.reset_index(drop=True)

    cleaned_text = []
    if STOPWORDS_REMOVAL==True:
        for t in data['Text']:
            cleaned_text.append(clean_line(t,0))
    else:
        for t in data['Text']:
            cleaned_text.append(clean_line(t,1))

    cleaned_sum = []
    for t in data['Summary']:
        cleaned_sum.append(clean_line(t,1))

    return cleaned_text, cleaned_sum

def make_csv(cleaned_text, cleaned_sum):
    '''Create a training csv for ease of use'''
    df = pd.DataFrame()

    df['Text']= cleaned_text
    df['Summary']= cleaned_sum

    df.Text = df.Text.apply(str)
    df.Summary = df.Summary.apply(str)

    df.to_csv("".join([PATH_TO_DATA,'training.csv']),index=False)

def preprocess(option):
    x,y = cleaner(option)
    make_csv(x,y)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Embedding

# %%
def count_words(count_dict, text):
    '''Count the number of occurrences of each word in a set of text'''
    for sentence in text:
        for word in sentence.split():
            if word not in count_dict:
                count_dict[word] = 1
            else:
                count_dict[word] += 1

def create_windex(txt_cleaned,summary_cleaned):
    '''Create a word index'''
    word_counts = {}
    count_words(word_counts, summary_cleaned)
    count_words(word_counts, txt_cleaned)
    print("Create Word Index - Done")
    return word_counts

def indexing_ematrix():
    '''Create Embedding Index'''
    embeddings_index = {}
    if EMBED_DIM ==300:
        f = open("".join([PATH_TO_MODELS,"glove.6B.300d.txt"]),encoding='utf-8')
    else: 
        f = open("".join([PATH_TO_MODELS,"glove.6B.100d.txt"]),encoding='utf-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    print("Create Embedding Index - Done")
    return embeddings_index
def count_missing_emb(embeddings_index,word_counts):
    '''Count missing words from embedding index'''
    missing_words = 0
    threshold = 20
    for word, count in word_counts.items():
        if count > threshold:
            if word not in embeddings_index:
                missing_words += 1
    missing_ratio = round(missing_words/len(word_counts),4)*100
    print("Count Missing Embedding - Done")
    return missing_ratio,threshold
def voc_n_int(word_counts,embeddings_index,threshold):
    '''Limit the vocab that we will use to words that appear ≥ threshold or are in GloVe'''
    vocab_to_int = {}

    value = 0
    for word, count in word_counts.items():
        if count >= threshold or word in embeddings_index:
            vocab_to_int[word] = value
            value += 1

    # Special tokens that will be added to our vocab
    codes = ["<UNK>","<PAD>","<EOS>","<GO>"]

    # Add codes to vocab
    for code in codes:
        vocab_to_int[code] = len(vocab_to_int)

    # Dictionary to convert integers to words
    int_to_vocab = {}
    for word, value in vocab_to_int.items():
        int_to_vocab[value] = word
    '''Debug
    usage_ratio = round(len(vocab_to_int) / len(word_counts),4)*100
    print("Total number of unique words:", len(word_counts))
    print("Number of words we will use:", len(vocab_to_int))
    print("Percent of words we will use: {}%".format(usage_ratio))
    Debug'''
    print("Vocabulary to Ints - Done")
    return vocab_to_int,int_to_vocab


def create_emb_matrix(vocab_to_int,embeddings_index):
    '''Create embeding matrix'''
    # Need to use 100 for embedding dimensions to match CN's vectors.
    embedding_dim = EMBED_DIM
    nb_words = len(vocab_to_int)

    # Create matrix with default values of zero
    word_embedding_matrix = np.zeros((nb_words, embedding_dim), dtype=np.float32)
    for word, i in vocab_to_int.items():
        if word in embeddings_index:
            word_embedding_matrix[i] = embeddings_index[word]
        else:
            # If word not in CN, create a random embedding for it
            new_embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
            embeddings_index[word] = new_embedding
            word_embedding_matrix[i] = new_embedding
    print("Create Embedding matrix - Done")
    return word_embedding_matrix

# Main running:
def create_embedding(txt_clean, sum_cleaned):
    '''Main function of creating embedding'''
    word_index_count = create_windex(txt_clean,sum_cleaned)
    emb_index = indexing_ematrix()
    _,threshold = count_missing_emb(emb_index,word_index_count)
    vocab2int,_ =voc_n_int(word_index_count,emb_index,threshold)
    word_embedding_matrix=create_emb_matrix(vocab2int,emb_index)
    return word_embedding_matrix, vocab2int

# %% [markdown]
# ### Spliting

# %%
def convert_to_ints(text, word_count, unk_count,vocab_to_int, eos=False):
    '''Convert words in text to an integer.
       If word is not in vocab_to_int, use UNK's integer.
       Total the number of words and UNKs.
       Add EOS token to the end of texts'''
    ints = []
    for sentence in text:
        sentence_ints = []
        for word in sentence.split():
            word_count += 1
            if word in vocab_to_int:
                sentence_ints.append(vocab_to_int[word])
            else:
                sentence_ints.append(vocab_to_int["<UNK>"])
                unk_count += 1
        if eos:
            sentence_ints.append(vocab_to_int["<EOS>"])
        ints.append(sentence_ints)
    return ints, word_count, unk_count
def check_unk(vocab_to_int,txt_cleaned,summary_cleaned):
    '''Count the unknown tokens'''
    # Apply convert_to_ints to clean_summaries and clean_texts
    word_count = 0
    unk_count = 0

    int_summaries, word_count, unk_count = convert_to_ints(summary_cleaned, word_count, unk_count,vocab_to_int)
    int_texts, word_count, unk_count = convert_to_ints(txt_cleaned, word_count, unk_count,vocab_to_int,eos=True)
    #unk_percent = round(unk_count/word_count,4)*100
    return int_texts,int_summaries,unk_count

def create_lengths(text):
    '''Create a data frame of the sentence lengths from a text'''
    lengths = []
    for sentence in text:
        lengths.append(len(sentence))
    return pd.DataFrame(lengths, columns=['counts'])

def max_sum_txt(int_texts,int_summaries):
    '''Use to set custom flexible max length but we decided to create a fixed length.'''
    lengths_summaries = create_lengths(int_summaries)
    lengths_texts = create_lengths(int_texts)
    global MAX_LEN_TXT,MAX_LEN_SUM
    #MAX_LEN_TXT1 = lengths_texts.describe()['counts']['max']
    #MAX_LEN_SUM1 = lengths_summaries.describe()['counts']['max']
    #if (MAX_LEN_TXT > MAX_LEN_TXT1):
    #  MAX_LEN_TXT = int(MAX_LEN_TXT1)
    #if (MAX_LEN_SUM > MAX_LEN_SUM1):
    #  MAX_LEN_SUM= int(MAX_LEN_SUM)
    return MAX_LEN_TXT,MAX_LEN_SUM

def unk_counter(sentence, vocab_to_int):
    '''Counts the number of time UNK appears in a sentence.'''
    unk_count = 0
    for word in sentence:
        if word == vocab_to_int["<UNK>"]:
            unk_count += 1
    return unk_count

def pre_tokenizing(dataset,int_texts,int_summaries,vocab_to_int):
    '''Create 2 array for text and summary.'''
    max_len_txt,max_len_summary=max_sum_txt(int_texts,int_summaries)
    # select the reviews and summaries whose length falls below or equal to **max_len_txt** and **max_len_summary**
    txt_cleaned =np.array(dataset['txt_cleaned'])
    summary_cleaned=np.array(dataset['summary_cleaned'])

    txt_short=[]
    summary_short=[]
    for i in range(len(txt_cleaned)):
        if(len(summary_cleaned[i].split())<=max_len_summary and
            len(txt_cleaned[i].split())<=max_len_txt and
            unk_counter(summary_cleaned[i].split(),vocab_to_int) <= 1 and
            unk_counter(txt_cleaned[i].split(),vocab_to_int) <= 1
        ):
            txt_short.append(txt_cleaned[i])
            summary_short.append(summary_cleaned[i])

    dataframe=pd.DataFrame({'txt':txt_short,'summary':summary_short})

    # add the **START** and **END** special tokens at the beginning and end of the summary.
    dataframe['summary'] = dataframe['summary'].apply(lambda x : 'sostok '+ x + ' eostok')
    return dataframe


def splitset(dataset,txt_cleaned,summary_cleaned,vocab_to_int):
    '''Main function of splitting data'''
    dataset['txt_cleaned']=txt_cleaned
    dataset['summary_cleaned']=summary_cleaned
    #Drop empty rows
    dataset.replace('', np.nan, inplace=True)
    dataset.dropna(axis=0,inplace=True)
    int_txt,int_sum,_=check_unk(vocab_to_int,txt_cleaned,summary_cleaned)
    df = pre_tokenizing(dataset,int_txt,int_sum,vocab_to_int)
    x_train,x_test,y_train,y_test=train_test_split(np.array(df['txt']),np.array(df['summary']),test_size=0.2,random_state=0,shuffle=True)
    x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.2)
    return x_train,x_test,x_val,y_train,y_test,y_val

# %% [markdown]
# ### Tokenizing

# %%
def max_featuretxt_count(x_train):
    '''Count max features for text'''
    tokenizer_x = Tokenizer()
    tokenizer_x.fit_on_texts(list(x_train))
    threshold=4
    count=0
    count_total=0
    frequancy=0
    frequancy_total=0
    for k,v in tokenizer_x.word_counts.items():
        count_total=count_total+1
        frequancy_total=frequancy_total+v
        if(v<threshold):
            count=count+1
            frequancy=frequancy+v
    return count_total-count

def tokenizing_text(max_features,x_train,x_test,x_val):
    '''Tokenizing text with pad sequences'''
    tokenizer_x = Tokenizer(num_words=max_features)
    tokenizer_x.fit_on_texts(list(x_train))

    x_tr_seq    =   tokenizer_x.texts_to_sequences(x_train)
    x_test_seq   =   tokenizer_x.texts_to_sequences(x_test)
    x_val_seq   =   tokenizer_x.texts_to_sequences(x_val)

    x_voc = tokenizer_x.num_words + 1
    x_train    =   pad_sequences(x_tr_seq,  maxlen=MAX_LEN_TXT, padding='post')
    x_test   =   pad_sequences(x_test_seq, maxlen=MAX_LEN_TXT, padding='post')
    x_val   =   pad_sequences(x_val_seq, maxlen=MAX_LEN_TXT, padding='post')
    return x_train,x_test,x_val,x_tr_seq,x_test_seq,x_val_seq,x_voc,tokenizer_x

def max_featuresum_count(y_train):
    '''Count max features for Summary'''
    tokenizer_y = Tokenizer()
    tokenizer_y.fit_on_texts(list(y_train))
    threshold=6
    count=0
    count_total=0
    frequancy=0
    frequancy_total=0
    for k,v in tokenizer_y.word_counts.items():
        count_total=count_total+1
        frequancy_total=frequancy_total+v
        if(v<threshold):
            count=count+1
            frequancy=frequancy+v
    return count_total-count

def tokenizing_sum(max_features,y_train,y_test,y_val):
    '''Tokenizing summary with pad sequences'''
    tokenizer_y = Tokenizer(num_words=max_features)
    tokenizer_y.fit_on_texts(list(y_train))

    #convert text to integer
    y_train_seq    =   tokenizer_y.texts_to_sequences(y_train)
    y_test_seq   =   tokenizer_y.texts_to_sequences(y_test)
    y_val_seq   =   tokenizer_y.texts_to_sequences(y_val)
    # padding zero to maximum
    y_train    =   pad_sequences(y_train_seq, maxlen=MAX_LEN_SUM, padding='post')
    y_test   =   pad_sequences(y_test_seq, maxlen=MAX_LEN_SUM, padding='post')
    y_val   =   pad_sequences(y_val_seq, maxlen=MAX_LEN_SUM, padding='post')
    # size of vocabulary
    y_vocab  =   tokenizer_y.num_words +1
    return y_train,y_test,y_val,y_train_seq,y_test_seq,y_val_seq,y_vocab,tokenizer_y

def cleanup_token(x,y):
    '''Remove lines contains only start and end token'''
    index=[]
    for i in range(len(y)):
        count=0
        for j in y[i]:
            if j!=0:
                count=count+1
        if(count==2):
            index.append(i)
    y=np.delete(y,index, axis=0)
    x=np.delete(x,index, axis=0)
    return x,y

def cleanup_blanksum(x,y):
    '''Remove blank lines'''
    index=[]
    for i in range(len(y)):
      if np.count_nonzero(y[i]==0)== len(y[i]):
        index.append(i)
    y=np.delete(y,index, axis=0)
    x=np.delete(x,index, axis=0)
    return x,y

# %% [markdown]
# ## Validating Functions

# %%
def make_valcsv(model_class,x_val,y_val,num_val=1000):
  '''Create a csv for validation process'''
  human_summ=[]
  mach_summ =[]
  for i in range(0,num_val):
    try:
      human_summ.append(model_class.sequence2summary(y_val[i]))
      mach_summ.append(model_class.greedy_decode(x_val[i].reshape(1,MAX_LEN_TXT)))
      print("Eval Step {0}",i)
    except(KeyError):
      pass
  df = pd.DataFrame()

  df['original']= human_summ
  df['generated']= mach_summ

  df.original = df.original.apply(str)
  df.generated = df.generated.apply(str)

  df.to_csv("".join([PATH_TO_DATA,model_class.name,'_val.csv']),index=False)
  return human_summ,mach_summ

def avg_rouge(candidates, references):
    '''Validate using ROUGE metrics'''
    avg_rouge1_scores = []
    avg_rouge2_scores = []
    avg_rougeL_scores = []
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    for i in range(0, min(len(candidates), len(references))):
        scores = scorer.score(candidates[i], references[i])
        avg_rouge1_scores.append(scores['rouge1'][2])
        avg_rouge2_scores.append(scores['rouge2'][2])
        avg_rougeL_scores.append(scores['rougeL'][2])
    return [sum(avg_rouge1_scores)/len(avg_rouge1_scores) , sum(avg_rouge2_scores)/len(avg_rouge2_scores), sum(avg_rougeL_scores)/len(avg_rougeL_scores)]

# %% [markdown]
# # MODEL BUILDING

# %%
class MyModel:
    def __init__(self,name,word_embedding_matrix,y_vocab,tokenizer_x,tokenizer_y):
        K.clear_session()
        self.name = name
        self.dim_latent = 300
        self.dim_emb=word_embedding_matrix.shape[1]
        self.encoder=None
        self.decoder=None
        self.tokenizer_x = tokenizer_x
        self.tokenizer_y = tokenizer_y
        self.reverce_targat_word_index=tokenizer_y.index_word
        self.reverce_sourse_word_index=tokenizer_x.index_word
        self.targat_word_index=tokenizer_y.word_index
        # Encoder
        self.en_input = Input(shape=(MAX_LEN_TXT,))
        #embedding layer
        self.en_embedding =  Embedding(word_embedding_matrix.shape[0], self.dim_emb,weights=[word_embedding_matrix],trainable=True)(self.en_input)

        #lstm 1
        self.en_lstm1 = LSTM(self.dim_latent,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
        self.en_output1, self.state_hidden1, self.state_c1 = self.en_lstm1(self.en_embedding)

        # lstm 2
        self.en_lstm2 = LSTM(self.dim_latent,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
        self.en_output2, self.state_hidden2, self.state_c2 =self. en_lstm2(self.en_output1)

        # lstm 3
        self.en_lstm3=LSTM(self.dim_latent, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
        self.en_outputs, self.state_hidden, self.state_c= self.en_lstm3(self.en_output2)

        # Set up the decoder
        self.dec_input = Input(shape=(None,))

        #embedding layer
        self.emb_layer_dec = Embedding(y_vocab,self.dim_emb,trainable=True)
        self.dec_embedding = self.emb_layer_dec(self.dec_input)

        self.dec_lstm = LSTM(self.dim_latent, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
        self.dec_output,self.dec_fwd_state, self.dec_back_state = self.dec_lstm(self.dec_embedding,initial_state=[self.state_hidden, self.state_c])

        # Attention layer
        self.attention_layer = AttentionLayer(name='attention_layer')
        self.attention_output = self.attention_layer([self.dec_output,self.en_outputs])

        # Concatinate attention input and decoder LSTM output
        self.dec_concate_input = Concatenate(axis=-1, name='concat_layer')([self.dec_output, self.attention_output])

        # Dense layer
        self.dec_dense =  TimeDistributed(Dense(y_vocab, activation='softmax'))
        self.dec_output = self.dec_dense(self.dec_concate_input)

        # Define the model
        self.model = Model([self.en_input, self.dec_input], self.dec_output)
        self.model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        self.model_path = "".join([PATH_TO_MODELS,self.name,".h5"])

    def save(self):
      '''Saving model weights'''
      self.model.save(self.model_path)

    def train(self,x_train,x_test,y_train,y_test,epoch=5):
      '''Training model with defined epochs and 128 batch'''
      self.checkpoint_path = "".join([PATH_TO_CHECKPOINT,self.name,"/cp.ckpt"])
      self.checkpoint_dir = os.path.dirname(self.checkpoint_path)
      earlystopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)
      checkpointing = tf.keras.callbacks.ModelCheckpoint(filepath=self.checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
      self.history=self.model.fit([x_train,
             y_train[:,:-1]],
             y_train.reshape(y_train.shape[0],y_train.shape[1], 1)[:,1:],
             epochs=epoch,
             callbacks=[earlystopping,checkpointing],
             batch_size=128,
             validation_data=([x_test,y_test[:,:-1]],
                              y_test.reshape(y_test.shape[0],
                                             y_test.shape[1], 1)[:,1:],
                            )

            )
      self.save()
      return self.history
    def load(self,cp=True):
      '''Load model from weight file or from checkpoint.'''
      if cp==True:
        latest = tf.train.latest_checkpoint("".join([PATH_TO_CHECKPOINT,self.name,"/cp.ckpt"]))
        self.model.load_weights(latest)
      else:
        self.model.load_weights("".join([PATH_TO_MODELS,self.name,".h5"]))
      return self.model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',metrics=['acc'])

    def create_en_de_model(self):
      ''' The inference step for the encoder and decoder '''
      # Encode the input sequence to get the feature vector
      self.encoder = Model(inputs=self.en_input,outputs=[self.en_outputs, self.state_hidden, self.state_c])

      # Decoder
      # Below tensors will hold the states of the previous time step
      decoder_state_input_h = Input(shape=(self.dim_latent,))
      decoder_state_input_c= Input(shape=(self.dim_latent,))
      dec_hid_stat_ip = Input(shape=(MAX_LEN_TXT,self.dim_latent))

      # Get the embeddings of the decoder sequence
      dec_embedding2= self.emb_layer_dec(self.dec_input)

      dec_output2, state_hidden2, state_c2 = self.dec_lstm(dec_embedding2, initial_state=[decoder_state_input_h, decoder_state_input_c])

      #attention inference
      attention_output_inf = self.attention_layer([dec_output2, dec_hid_stat_ip])
      dec_inf_con = Concatenate(axis=-1, name='concat')([dec_output2, attention_output_inf])

      # A dense softmax layer to generate prob dist. over the target vocabulary
      dec_output2 = self.dec_dense(dec_inf_con)

      # decoder model
      self.decoder = Model(
      [self.dec_input] + [dec_hid_stat_ip,decoder_state_input_h, decoder_state_input_c],
      [dec_output2] + [state_hidden2, state_c2])

    def greedy_decode(self,input_sequence):
      '''Predict next word by choosing the word with highest probability'''
      if self.encoder == None or self.decoder==None:
          self.create_en_de_model()
      # Encode the input.
      en_out, en_h, en_c = self.encoder.predict(input_sequence)

      # Generate empty target sequence of length 1.
      targat_seq = np.zeros((1,1))

      # the first word of target sequence with the start word.
      targat_seq[0, 0] = self.targat_word_index['sostok']

      stop_cond = False
      dec_sent = ''
      while not stop_cond:
        output_tokans, h, c = self.decoder.predict([targat_seq] + [en_out, en_h, en_c])
        sample_index_tokan = np.argmax(output_tokans[0, -1, :])
        sample_tokan = self.reverce_targat_word_index[sample_index_tokan]

        if(sample_tokan!='eostok'):
            dec_sent += ' '+sample_tokan

        # Exit condition
        if (sample_tokan == 'eostok'  or len(dec_sent.split()) >= (MAX_LEN_SUM-1)):
            stop_cond = True

        # Update the target sequence.
        targat_seq = np.zeros((1,1))
        targat_seq[0, 0] = sample_index_tokan

        # Update internal states
        en_h, en_c = h, c

      return dec_sent
    def sequence2summary(self,input_sequence):
      '''Convert Sequences to Summary'''
      string=''
      for i in input_sequence:
        if((i!=0 and i!=self.targat_word_index['sostok']) and i!=self.targat_word_index['eostok']):
            string=string+self.reverce_targat_word_index[i]+' '
      return string

    def sequence2text(self,input_sequence):
      '''Convert Sequences to Text'''
      string=''
      for i in input_sequence:
        if(i!=0):
          string=string+self.reverce_sourse_word_index[i]+' '
      return string

    def summarize(self,input_text):
      '''Custom summary function'''
      list_txt= []
      list_txt.append(input_text)
      list_tr=self.tokenizer_x.texts_to_sequences(list_txt)
      list2seq=pad_sequences(list_tr,  maxlen=MAX_LEN_TXT, padding='post')
      summary = self.greedy_decode(list2seq[0].reshape(1,MAX_LEN_TXT))
      return summary
    
    def evaluate(self,x,y):
      '''Re-evalute model after loading. Will only cost about 10% time of normal training time'''
      # Re-evaluate the model
      loss, acc = self.model.evaluate([x, y[:,:-1]],
             y.reshape(y.shape[0],y.shape[1], 1)[:,1:], verbose=1)
      print("Restored model, accuracy: {:5.2f}%".format(100 * acc))

# %% [markdown]
# # MAIN

# %% [markdown]
# ## Loading Dataset

# %%
'''Remember to delete old training csv when using new hyperparameter or choosing new embedding dimension.'''
import os
if os.path.isfile("".join([PATH_TO_DATA,'training.csv']))==False:
    preprocess('review')
data = pd.read_csv("".join([PATH_TO_DATA,'training.csv']))
data['Text'] = data['Text'].astype(str)
data['Summary'] = data['Summary'].astype(str)

# %% [markdown]
# ## Creating Embedding

# %%
#Embbeding
embb_matrix,vocab_to_int = create_embedding(data['Text'].tolist(), data['Summary'].tolist())
# Out:
# Create Word Index - Done
# Create Embedding Index - Done
# Count Missing Embedding - Done
# Vocabulary to Ints - Done
# Create Embedding matrix - Done

# %% [markdown]
# ## Splitting Data

# %%
#Split-set
x_train,x_test,x_val,y_train,y_test,y_val = splitset(data,data['Text'].tolist(), data['Summary'].tolist(),vocab_to_int)

#Tokenizing text
maxfeat = max_featuretxt_count(x_train)
x_train,x_test,x_val,x_tr_seq,x_test_seq,x_val_seq,x_voc,tokenizer_x = tokenizing_text(maxfeat,x_train,x_test,x_val)

#Tokenizing sum
maxfeat = max_featuresum_count(y_train)
y_train,y_test,y_val,y_tr_seq,y_test_seq,y_val_seq,y_voc,tokenizer_y = tokenizing_sum(maxfeat,y_train,y_test,y_val)

x_train,y_train = cleanup_token(x_train,y_train)
x_test,y_test = cleanup_token(x_test,y_test)
x_val,y_val = cleanup_token(x_val,y_val)

# %% [markdown]
# ## Training / Loading

# %%
'''When loading, try to match the model name to the weight file name.'''
TRAINING = False

current = MyModel("400000_300d_nostop_100_20",embb_matrix,y_voc,tokenizer_x,tokenizer_y)
current.model.summary()

if TRAINING:
    current.train(x_train,x_test,y_train,y_test,epoch=20)
else:
    # Load the previously saved weights
    current.load(cp=False)
model = current.model
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 100)]                0         []
#
#  embedding (Embedding)       (None, 100, 300)             1650390   ['input_1[0][0]']
#                                                           0
#
#  lstm (LSTM)                 [(None, 100, 300),           721200    ['embedding[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 100, 300),           721200    ['lstm[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  embedding_1 (Embedding)     (None, None, 300)            1791900   ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 100, 300),           721200    ['lstm_1[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  lstm_3 (LSTM)               [(None, None, 300),          721200    ['embedding_1[0][0]',
#                               (None, 300),                           'lstm_2[0][1]',
#                               (None, 300)]                           'lstm_2[0][2]']
#
#  attention_layer (Attention  (None, None, 300)            0         ['lstm_3[0][0]',
#  )                                                                   'lstm_2[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 600)            0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  time_distributed (TimeDist  (None, None, 5973)           3589773   ['concat_layer[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 24770373 (94.49 MB)
# Trainable params: 24770373 (94.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Validating

# %%
'''Re-evaluate the model Accuarcy with train set'''
#Evaluate Model's Accuarcy
#current.evaluate(x_train,y_train)

# %%
'''Make a csv file for safe keeping'''
human_summ,mach_summ = make_valcsv(current,x_val,y_val,num_val=x_val.shape[0])
# Out:
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 0
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 1
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 2
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# Eval Step {0} 3
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 4
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 5
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 6
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# Eval Step {0} 7
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 8
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 9
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# Eval Step {0} 10
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 11
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 12
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 13
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 14
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# Eval Step {0} 15
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 16
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 17
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 18
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 19
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 20
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 21
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 22
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 23
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# Eval Step {0} 24
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 25
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 26
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 27
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 28
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 29
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 30
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 31
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 32
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# Eval Step {0} 33
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 34
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 35
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# Eval Step {0} 36
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# Eval Step {0} 37
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 38
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 39
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# Eval Step {0} 40
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 41
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 42
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 43
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 44
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 45
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 46
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 47
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 48
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# Eval Step {0} 49
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# Eval Step {0} 50
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 51
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 52
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# Eval Step {0} 53
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 54
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 55
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# Eval Step {0} 56
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 57
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 58
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 59
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 60
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# Eval Step {0} 61
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 62
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# Eval Step {0} 63
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# Eval Step {0} 64
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 65
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 66
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 67
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 68
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 69
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 70
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 71
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 72
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 73
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 74
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 75
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 44ms/step
# Eval Step {0} 76
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 77
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 78
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# Eval Step {0} 79
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# Eval Step {0} 80
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 81
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 82
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 83
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 84
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Eval Step {0} 85
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 86
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 87
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 88
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 89
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 90
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 91
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 92
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 93
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 94
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 95
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 96
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 97
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 98
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 99
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 100
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 69ms/step
# Eval Step {0} 101
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# Eval Step {0} 102
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 103
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 104
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 105
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 106
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 107
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# Eval Step {0} 108
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 109
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 110
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 111
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# Eval Step {0} 112
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 113
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 114
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# Eval Step {0} 115
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 116
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 117
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 118
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 119
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 120
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 121
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 122
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 123
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 124
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 125
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 126
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 127
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 128
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 129
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 130
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 131
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 132
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 133
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 134
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 135
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 136
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 137
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 138
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 139
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 140
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 141
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 142
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 143
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 144
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 145
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 146
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 147
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 148
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 149
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 150
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 151
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 152
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 153
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 154
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 155
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# Eval Step {0} 156
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Eval Step {0} 157
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 158
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 159
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 160
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 161
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 162
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 163
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 164
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 165
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 166
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 167
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# Eval Step {0} 168
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 169
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 170
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 171
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# Eval Step {0} 172
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 173
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 174
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 175
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 176
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 177
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 178
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 179
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# Eval Step {0} 180
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 181
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Eval Step {0} 182
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# Eval Step {0} 183
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 184
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 185
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 186
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Eval Step {0} 187
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Eval Step {0} 188
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Eval Step {0} 189
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 25ms/step
# ...
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 94ms/step
# Eval Step {0} 5374
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 81ms/step
# Eval Step {0} 5375
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 127ms/step
# Eval Step {0} 5376
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 110ms/step
# Eval Step {0} 5377
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 121ms/step
# Eval Step {0} 5378
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 121ms/step
# Eval Step {0} 5379
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 132ms/step
# Eval Step {0} 5380
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 86ms/step
# Eval Step {0} 5381
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 132ms/step
# Eval Step {0} 5382
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 107ms/step
# Eval Step {0} 5383
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 110ms/step
# Eval Step {0} 5384
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 75ms/step
# Eval Step {0} 5385
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 120ms/step
# Eval Step {0} 5386
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 75ms/step
# Eval Step {0} 5387
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 100ms/step
# Eval Step {0} 5388
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 106ms/step
# Eval Step {0} 5389
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 99ms/step
# Eval Step {0} 5390
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 122ms/step
# Eval Step {0} 5391
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 91ms/step
# Eval Step {0} 5392
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 139ms/step
# Eval Step {0} 5393
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 101ms/step
# Eval Step {0} 5394
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 94ms/step
# Eval Step {0} 5395
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 108ms/step
# Eval Step {0} 5396
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 157ms/step
# Eval Step {0} 5397
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 113ms/step
# Eval Step {0} 5398
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 111ms/step
# Eval Step {0} 5399
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 106ms/step
# Eval Step {0} 5400
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 76ms/step
# Eval Step {0} 5401
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 119ms/step
# Eval Step {0} 5402
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 133ms/step
# Eval Step {0} 5403
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 89ms/step
# Eval Step {0} 5404
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 113ms/step
# Eval Step {0} 5405
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 86ms/step
# Eval Step {0} 5406
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 103ms/step
# Eval Step {0} 5407
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 106ms/step
# Eval Step {0} 5408
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 114ms/step
# Eval Step {0} 5409
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 86ms/step
# Eval Step {0} 5410
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# Eval Step {0} 5411
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 109ms/step
# Eval Step {0} 5412
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 114ms/step
# Eval Step {0} 5413
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 114ms/step
# Eval Step {0} 5414
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 121ms/step
# Eval Step {0} 5415
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 119ms/step
# Eval Step {0} 5416
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 157ms/step
# Eval Step {0} 5417
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 86ms/step
# Eval Step {0} 5418
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 119ms/step
# Eval Step {0} 5419
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 108ms/step
# Eval Step {0} 5420
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 91ms/step
# Eval Step {0} 5421
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 135ms/step
# Eval Step {0} 5422
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 89ms/step
# Eval Step {0} 5423
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# Eval Step {0} 5424
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 107ms/step
# Eval Step {0} 5425
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 98ms/step
# Eval Step {0} 5426
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 116ms/step
# Eval Step {0} 5427
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 127ms/step
# Eval Step {0} 5428
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# Eval Step {0} 5429
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 129ms/step
# Eval Step {0} 5430
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 81ms/step
# Eval Step {0} 5431
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 85ms/step
# Eval Step {0} 5432
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 114ms/step
# Eval Step {0} 5433
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# Eval Step {0} 5434
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 123ms/step
# Eval Step {0} 5435
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 138ms/step
# Eval Step {0} 5436
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 119ms/step
# Eval Step {0} 5437
# [0.14133075728671451, 0.032170655138658126, 0.14020987967631868]

# %%
'''Avergae ROUGE metric F1-score'''
avg_rouge(mach_summ,human_summ)
# Out:
# [0.14133075728671451, 0.032170655138658126, 0.14020987967631868]

# %%
'''Print out some cases from validation set'''
for i in range(0,50):
    print("Review:",current.sequence2text(x_val[i]))
    print("Original summary:",current.sequence2summary(y_val[i]))
    print("Predicted summary:",current.greedy_decode(x_val[i].reshape(1,MAX_LEN_TXT)))
    print("\n")
# Out:
# Review: bread moist flavorful however ordered pack arrived every single dented people buy product long term storage definitely problem probably buy bread future purchase another vendor
# Original summary: dented cans
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# Predicted summary:  great product
#
#
# Review: lucky enough able buy bread local farmer market go back every saturday morning buy absolutely delicious high cinnamon sugar ratio right
# Original summary: delicious cinnamon loaf
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# Predicted summary:  best gluten free bread
#
#
# Review: typical bread mix thought ordering like cinnamon bread comes several recipes box used make banana nut muffins coffee cake muffins absolutely delicious spongy gritty texture gluten free taste even gluten eating family loves nobody would know gluten free unless told make half box time yields muffins keep rest family eating freeze quick breakfast go still delicious defrosting microwave complaint mix bit pricey amazon usually best price pack continue look sales definitely one thing keep hand times
# Original summary: one of my favorite gluten free products
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted summary:  best gluten free bread mix
#
#
# Review: bought tassimo darker starbucks coffees available gone tried many european brands available well brand stands starbucks personal taste test carte noire little funny carte noire supermarket brand france taste full flavored without overly bitter carte noire kenya one favorites espresso discs starbucks coffee discs bolder darker intense strong coffees like starbucks verona starbucks kitamu less bitter straight espresso volume produced well coffee cup overflows espresso cup finally kenya programmed tassimo add crema dark foam top espresso short cup coffee tassimo like darker starbucks blends want check one european brands one try
# Original summary: bold coffee in between espresso and coffee
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# Predicted summary:  smooth and smooth
#
#
# Review: want strong full bodied coffee never bitter without caffeine always fresh whole beans amazing aroma disappointed
# Original summary: best decaf have had
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# Predicted summary:  best coffee ever
#
#
# Review: found amazon glad buying one time counter local market soft flavorful distinct salty flavor exactly sea salt caramel glad find bags give gifts
# Original summary: tasty little gems
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  great salt
#
#
# Review: liked product past contents every shipment thin curdled peculiar grayish cast think coconut milk powder probably safest bet ordering coconut milk cream line
# Original summary: big disappointment
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted summary:  not as good as the real thing
#
#
# Review: effect friends try stated feel anything energy shot either age range tested years old
# Original summary: no effect
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted summary:  great product
#
#
# Review: im always need keeps dog busy away chewing stuff shouldnt couple stocked
# Original summary: my dog loves it
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted summary:  dog loves it
#
#
# Review: expected product fulfilled satisfaction expectation invited children birthday party
# Original summary: party candies
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  not as pictured
#
#
# Review: husband loves flavor always seem find best price cannot seem keep shelf
# Original summary: cup yummies
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# Predicted summary:  great product
#
#
# Review: could believe much juice tasted like coconut water coconut pure refreshing buy
# Original summary: taste like it is straight from the
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# Predicted summary:  coconut water
#
#
# Review: cool idea item poorly packaged cover set stained spices leaked containers since food item completely sealed individual spice containers sealed box came non sealed plastic bag also kit bit smaller anticipating ratio mixed spices pure spices little dissapointing would liked get pure spices
# Original summary: should have been better packaged
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  nice plant
#
#
# Review: debated ordering kind fragile shipment problems ha maybe would trust amazon ups people got working grocery store another reason debated ordering course salt course saltines bunch compared lot snacks strangely enough less salt alternatives guess tastes mask little bit salt comes right normally worry things health nutrition boxes lot tend chow lot good plenty time left expiration date months worry prices everything fluctuate got good deal
# Original summary: tasty
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  great salt
#
#
# Review: purchased pound bag licorice allsorts christmas gift mom sadly say embarassed give gift inside bag covered candy piece candy also covered black black licorice looks like serious melting took place along line going throw anyone know get refund listened people said product previous reviews disappointed purchase
# Original summary: extremely disappointed
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# Predicted summary:  not the best
#
#
# Review: stuff good think best taste little bland compared sauces really pack heat would think hot meant hot like mild try taco bell
# Original summary: taco bell sauce
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# Predicted summary:  good stuff
#
#
# Review: recently switched illy espresso membership amazon lavazza subscription glad care loosely packed lavazza pods produce better tasting much stronger coffee illy mention price difference
# Original summary: great espresso pods
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# Predicted summary:  great coffee
#
#
# Review: ordered sister used eat little three months gets visit see ate half planning give half away part xmas gifts ask purchased amazon knowing sour squeeze pops everyone likes sweet ones sweet ones original squeeze pops vendors title sour squeeze pops sour squeeze pops guys even put word sour anywhere description way know ordering sour version enlarge picture item hunt word sour box felt deceived would rather business another vendor buck two dishonest one
# Original summary: mis title warning these are sour pops not the sweet ones
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# Predicted summary:  not what expected
#
#
# Review: tried pamela regular shortbread cookies vast improvement world passes plain ones shortbread best bland biscuit base dough close shortbread ever gluten free great flavor balance sweet savory makes shortbread good nice crisp texture would purchase
# Original summary: good
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  best gluten free cookies
#
#
# Review: love coffee drink three four brands cups depending mood coffee strong strong let tell coming someone cannot drink coffee empty stomach someone trouble digesting starbucks mocha put water level high fill travel mug plenty strong go french roasts etc amazon brilliant fast service convenient buy cup coffees online find types flavors want store stores limited cup offerings
# Original summary: good brew little strong
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# Predicted summary:  great coffee
#
#
# Review: quest go natural way oil good cooking great moisturizer hair body
# Original summary: coconut oil
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted summary:  great product
#
#
# Review: made cookies product awesome gave cookies friends try also loved cannot wait try
# Original summary: cookies
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  great cookies
#
#
# Review: bad coffee little bitter like coffee
# Original summary: not bad coffee
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 52ms/step
# Predicted summary:  not bitter
#
#
# Review: first time protien shakes first one didnt go well another actually liked ive scoops ice water banana breakfast lunch snack nuts healthy dinner already pds definetly recommend product ordered vanilla ice cream flavor cant wait try also shopped around price cheapest ive found almost
# Original summary: like
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# Predicted summary:  great product
#
#
# Review: ever wish sauce taco bell squeeze bottle one seems close gonna get also much like sauce spicy worry burning mouth touch tangy tasty stuff healthy mind taco bell expecting
# Original summary: more please
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# Predicted summary:  the best
#
#
# Review: pretty good make healthy snack prefer real apples always hand since organic think good buy especially subscribe save
# Original summary: pretty tasty
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 49ms/step
# Predicted summary:  good snack
#
#
# Review: love tomato soup tasted every brand available product absolutely best superior flavor bits tomato included found anything comparable even restaurant
# Original summary: the best tomato soup ever
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 45ms/step
# Predicted summary:  best soup ever
#
#
# Review: made hair extremely greasy thick wiry hair got thought would give really good deep condition hair turned greasy difficult get ended using dish soap like another reviewer hair got really dry ended using old vo hot oil treatment brought hair back life admit sweating
# Original summary: very greasy
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# Predicted summary:  not for me
#
#
# Review: son allergic gluten picky eater eat hot dogs buns
# Original summary: great product
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# Predicted summary:  my cats love these
#
#
# Review: little diabetic shih tzu lily notorious hating anything new constantly search healthy new treats give insulin shot received liver flavor lickety stik prepared donate local animal shelter sure lily would turn nose lo behold liked took minute two figure get treat squeezed bottle hard dripped floor lily quickly lapped think ball turned easily determined try get treat juice bottle think great idea giving stars packaging hard read ball seem turn readily
# Original summary: lily liked it
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# Predicted summary:  great for aggressive chewers
#
#
# Review: year old neutered male domestic short hair year old spayed female domestic short hair overall healthy happy excited put cats food extensive research high protein grain free several great reviews innova senior little dry really love food however since starting feed wellness core days ago kitties diarrhea every time use litterbox owned cats entire lives never diarrhea thing changed diet although already relatively high protein low carb diet think even higher level protein fat food might much digestive tracts handle stopped feeding food expect condition clear soon
# Original summary: caused both my cats to have diarrhea
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# Predicted summary:  excellent product
#
#
# Review: use provide food goldfish two natural especially early spring early winter ice covering whole pond fish dug winter yet natural food seems bit lean normally feed first know fish feeders bought pet store several years ago length wanted something use treat occasion stop pond chilly weather fish hanging around sunning fish like pellets float top long time giving opportunity find sinks muddy bottom live long way stores amazon favorite source stuff like everything else matter great prices great shipping ups crowds great customer service great selection could go amazon
# Original summary: tasty treat for
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  great for our dogs
#
#
# Review: cat loved tuna treats package front kept meowing treats given kept licking treats started break flake apart finally gobbled treat bag comes rather large sticks tuna broke apart one pieces gave rd stick time case would get sick throw treats smell exactly like canned tuna would eat flakes like well people complained packaging really problem used pair scissors cut top part resealable bag opened able reseal fine well storage fridge overall stars cat knocked one star price kinda insane cat treats would something would normally buy
# Original summary: cat loved them
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# Predicted summary:  cat loves them
#
#
# Review: used product years put handful dried apples bottom bowl put top zap add walnuts dried cranberries yummy
# Original summary: great product
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# Predicted summary:  great for the office
#
#
# Review: husband like lot bomba para beautiful faster delivery item perfect condition thank much
# Original summary: very good
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  great
#
#
# Review: mean asian sauces easily best sauce ever put everything gotten hand go way see else latest thing pouring peanuts coating peanuts sauce eat nuts spoon keep hands clean sounds gross delicious
# Original summary: best sauce ever
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# Predicted summary:  best sauce ever
#
#
# Review: great buy love rich taste comes fair price delivery fast packaging good subscribe save makes easy get new favorite coffee
# Original summary: what buy
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# Predicted summary:  great coffee
#
#
# Review: wonderful cocoa powder chocolate needs even special organic free pesticides harmful chemicals
# Original summary: now cocoa
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  great cocoa
#
#
# Review: walmart sells cake mix less per box expect much better amazon ripping people deal
# Original summary: how is this good deal
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# Predicted summary:  overpriced
#
#
# Review: canela spanish cinnamon new starbucks natural fusions coffee hint brazil evokes ana rita song bengal woman cinnamon cinnamon commonly used flavor coffee south america starbucks taste alright cinnamon strong terrible coffee great either cinnamon subtle point non existence starbucks cinnamon coffee best accompanied brazilian cafe brazil hint exotic okay
# Original summary: cafe
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# Predicted summary:  not as good as the real thing
#
#
# Review: bought initial treat ball vet office kept golden busy time knew find refills cheaper sell loves sees get package follows nosing hand trying sneak hand works awhile pops treat ball still keep busy would excellant dogs crates
# Original summary: great to keep dogs busy
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 66ms/step
# Predicted summary:  great for small dogs
#
#
# Review: brand best tasting ever bitter flavor filtering tea brewing assures clear beverage
# Original summary: tasty tea
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# Predicted summary:  best green tea
#
#
# Review: best tea ever smaller pyramid bag original boxed pg tips like better perfect one cup tea
# Original summary: best tea ever
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# Predicted summary:  best tea ever
#
#
# Review: expected thought would dried crunchy except like cheeto without cheese maybe even greasier would read product information little closely may noticed baked snack formed pea pod shape dried peas little rice healthy either make sure read nutrition facts love cheetos looking snack little dietary nutritional value
# Original summary: wish would read the details more
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 37ms/step
# Predicted summary:  not bad
#
#
# Review: wow difference flavor fresh indus ceylon cinnamon cinnamon powders use teaspoonful daily protein drink keeps energy level even hours dash great brewed coffee highly recommended
# Original summary: fragrant flavorful the best ground cinnamon
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  great product
#
#
# Review: one biggest challenge going vegan leaving parmesan cheese behind read books realized many recipes called versatile nutritional yeast com good blog post first use receiving product top pasta delicious using often many different recipes going order another bag
# Original summary: what parmesan cheese
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# Predicted summary:  great product
#
#
# Review: love oskri bars tried gluten free continue buy delicious busy days oskri bars thing eat meals satisfying plus love fact see ingredients nuts cranberries ect
# Original summary: delicious nutritious
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  delicious
#
#
# Review: tried mio flavors least favorite taste well like pool water chlorine bleach taste also tastes little peachy guess accurate description would peachy seriously like peach taste mind overly artificial taste like personally take pass flavor
# Original summary: taste is ok artificial tasting
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# Predicted summary:  not bad
#
#
# Review: excited saw vintage cracker jack box read review arrived one buy grocery store unfortunately cannot return also unhappy really wanted vintage box cracker barrel sells genuine vintage box know
# Original summary: am not happy
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# Predicted summary:  not as pictured
#
#
# Review: cumin expensive spice small bottles supermarkets love cumin season various recipes buy two share
# Original summary: great bargain
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted summary:  good value
